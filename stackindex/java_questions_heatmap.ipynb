# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()


df = pd.read_csv('java_st_questions.csv')

print(df)
print(type(df))
print(df.shape)
# Out:
#      year      month  questions
# 0    2008    January          0
# 1    2008   February          0
# 2    2008      March          0
# 3    2008      April          0
# 4    2008        May          0
# 5    2008       June          0
# 6    2008       July          0
# 7    2008     August        219
# 8    2008  September        811
# 9    2008    October        960
# 10   2008   November       1141
# 11   2008   December       1155
# 12   2009    January       1159
# 13   2009   February       1208
# 14   2009      March       1444
# 15   2009      April       1539
# 16   2009        May       1827
# 17   2009       June       2122
# 18   2009       July       2197
# 19   2009     August       2269
# 20   2009  September       2278
# 21   2009    October       2512
# 22   2009   November       2622
# 23   2009   December       2773
# 24   2010    January       3589
# 25   2010   February       3735
# 26   2010      March       3903
# 27   2010      April       4184
# ...

# %%
df_java = df.pivot("month", "year", "questions")

# %%
print(df_java.shape)
# Out:
# (12, 10)

# %%
sns.heatmap(df_java, annot=True, fmt="d", linewidths=.5)
