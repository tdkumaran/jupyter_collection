# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()


df = pd.read_csv('python_st_questions.csv')

print(df)
print(type(df))
print(df.shape)
# Out:
#      year      month  questions
# 0    2008    January          0
# 1    2008   February          0
# 2    2008      March          0
# 3    2008      April          0
# 4    2008        May          0
# 5    2008       June          0
# 6    2008       July          0
# 7    2008     August        126
# 8    2008  September        430
# 9    2008    October        453
# 10   2008   November        513
# 11   2008   December        545
# 12   2009    January        632
# 13   2009   February        633
# 14   2009      March        766
# 15   2009      April        768
# 16   2009        May       1003
# 17   2009       June       1046
# 18   2009       July       1143
# 19   2009     August       1165
# 20   2009  September       1169
# 21   2009    October       1424
# 22   2009   November       1552
# 23   2009   December       1562
# 24   2010    January       1817
# 25   2010   February       1872
# 26   2010      March       1953
# 27   2010      April       2017
# ...

# %%
df_python = df.pivot("month", "year", "questions")

# %%
print(df_python.shape)
# Out:
# (12, 9)

# %%
sns.heatmap(df_python, annot=True, fmt="d", linewidths=.5)
