# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()


df = pd.read_csv('python_st_questions.csv')

print(df)
print(type(df))
print(df.shape)
# Out:
#     year      month  questions
# 0   2016    january      12424
# 1   2016   february      12440
# 2   2016      march      12893
# 3   2016      april      12949
# 4   2016        may      13012
# 5   2016       june      13014
# 6   2016       july      13208
# 7   2016     august      13334
# 8   2016  september      13622
# 9   2016    october      13777
# 10  2016   november      14176
# 11  2016   december      14303
# 12  2017    january      14394
# 13  2017   february      14903
# 14  2017      march      15757
# 15  2017      april      16181
# 16  2017        may      16214
# 17  2017       june      16304
# 18  2017       july      16955
# 19  2017     august      17288
# 20  2017  september      17980
# 21  2017    october      18006
# 22  2017   november      18745
# 23  2017   december      18946
# <class 'pandas.core.frame.DataFrame'>
# (24, 3)

# %%
df1 = df.pivot("month", "year", "questions")

# %%
print(df1.shape)
# Out:
# (12, 2)

# %%
sns.heatmap(df1, annot=True, fmt="d", linewidths=.5)
